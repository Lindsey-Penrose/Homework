# %%
arr = [4, 11, -3, 16]

def highestvalue(nums):
    highest = nums[0]
    for i in nums:
        if i > highest:
            highest = i
    return highest
    # if nums[0] > nums[1] and nums[0]>nums[2]:
    #     print(nums[0])
    # elif nums[1] > nums[0] and nums[1] > nums[2]:
    #     print(nums[1])
    # elif nums[2] > nums[0] or nums[2] > nums[1]:
    #     print(nums[2])
  
print(highestvalue([4, 11, -3, 23, 16]))
print(highestvalue(arr))
# Out:
# 23
# 16
