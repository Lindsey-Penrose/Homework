# %% [markdown]
# # Python Homework
#
#
# ### Data Types
#
# 1. ***What is an algorithm?***
#
#     An algorithm is a series of steps taken to solve a problem.
# 2. ***Variable names may not start with certain characters- name two.***
#
#     Variable names can't start with numbers or special characters.
#
# 3. **What is a semantic error?**
#
#     You get output that is technically correct but isn't what you were looking for.
# 4. **What is the #1 rule of coding/debugging?**
#
#     Keep it simple.
# 5. **List 5 Python reserved words**
#
#     None, elif, else, finally, for

# %%
# 6. Write multi-line string with name, fav food, dream job

aboutMe = """My name is Lindsey
I love to eat noodles
My dream job is to be a capybara keeper"""
print(aboutMe)
# Out:
# My name is Lindsey
# I love to eat noodles
# My dream job is to be a capybara keeper

# %%
#7 Assigning data types to variables

TheFroot = ("banana", "apple", "pomelo")
age = 26
female = True
myFavAnimals = ["Capybara", "cats", "blobfish"]
SteveIrwin = "She's a beaut, i'nt she?"

print(len(SteveIrwin))
print(myFavAnimals[0:3])
# Out:
# 24
# ['Capybara', 'cats', 'blobfish']

# %%
#8 replacing a word
savvy = "Learning Data Analytics and Python is Awesome!"

print(savvy[5:23])
newSavvy = savvy.replace("Awesome!", "Great!")
print(newSavvy)
# Out:
# ing Data Analytics
# Learning Data Analytics and Python is Great!

# %%
#9 Finishing a sentence with {}

name, age, length = "Lindsey", 26, tall
miniBio = "Hi, my name is {}, I am {} and {} years old today."
print(miniBio.format(name, tall, age))
tall = float(5.7)
# Out:
# Hi, my name is Lindsey, I am 5.7 and 26 years old today.

# %%
#10 Creating list of mixed data types

myHobbies = ["crochet", 5, float(2.5), "cross stitch", "reading"]
myHobbies[1] = "dancing"
myHobbies.append("eating")
myHobbies.append("swimming")
myHobbies.append("racing")
print(len(myHobbies))

secondList = myHobbies[0:3]
print(secondList)

myHobbies.extend(secondList)
print(myHobbies)

simList = ["I", "love", "what", "I'm", "learning"]
simList.sort()
print(simList)
simList2 = simList.copy()
secondList.extend(simList)
print(secondList)
# Out:
# 8
# ['crochet', 'dancing', 2.5]
# ['crochet', 'dancing', 2.5, 'cross stitch', 'reading', 'eating', 'swimming', 'racing', 'crochet', 'dancing', 2.5]
# ['I', "I'm", 'learning', 'love', 'what']
# ['crochet', 'dancing', 2.5, 'I', "I'm", 'learning', 'love', 'what']

# %%
#13 create a dictionary

places = {
"Theme Park" : "Disney",
"Restaurant" : "Cheesecake Factory",
"Airport" : "ORD",
"Cosmetics Store" : "E.L.F.",
"Mall" : "West County"
}
import copy 
newDict = copy.deepcopy(places)

placesKeys = places.items()
print(placesKeys)

yum = places.get("Restaurant")
print(yum)

newDict.update({"Airport": "Lindsey"})
print(newDict)

newDict ["Color"] = "Green"
newDict ["Spectrum"] = "Red", "Orange", "Yellow", "Blue", "Indigo", "Violet"
Thekey = newDict.keys()
print(Thekey)

newDict.values()
print(newDict)

newDict.pop("Theme Park")
print(newDict)

newDict.clear()
print(newDict)
# Out:
# dict_items([('Theme Park', 'Disney'), ('Restaurant', 'Cheesecake Factory'), ('Airport', 'ORD'), ('Cosmetics Store', 'E.L.F.'), ('Mall', 'West County')])
# Cheesecake Factory
# {'Theme Park': 'Disney', 'Restaurant': 'Cheesecake Factory', 'Airport': 'Lindsey', 'Cosmetics Store': 'E.L.F.', 'Mall': 'West County'}
# dict_keys(['Theme Park', 'Restaurant', 'Airport', 'Cosmetics Store', 'Mall', 'Color', 'Spectrum'])
# {'Theme Park': 'Disney', 'Restaurant': 'Cheesecake Factory', 'Airport': 'Lindsey', 'Cosmetics Store': 'E.L.F.', 'Mall': 'West County', 'Color': 'Green', 'Spectrum': ('Red', 'Orange', 'Yellow', 'Blue', 'Indigo', 'Violet')}
# {'Restaurant': 'Cheesecake Factory', 'Airport': 'Lindsey', 'Cosmetics Store': 'E.L.F.', 'Mall': 'West County', 'Color': 'Green', 'Spectrum': ('Red', 'Orange', 'Yellow', 'Blue', 'Indigo', 'Violet')}
# {}
